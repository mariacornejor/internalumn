# %%
import statistics as st
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
atri = list(data.columns)

# %%
i = 0
def pintargrafico(data,atri,i):
    print("Atributo: " + atri[i])
    datitos = data.iloc[:, i].tolist()
    vdat = st.variance(datitos)
    print(f"Varianza: ")
    print("{0:.7f}".format(vdat))
    plt.plot(datitos)
    plt.xlabel("Datos")
    plt.ylabel("Varianza")

# %%
pintargrafico(data,atri,2)
# Out:
# Atributo: radius_mean
# Varianza:
# 12.4189201

# %%
pintargrafico(data,atri,3)
# Out:
# Atributo: texture_mean
# Varianza:
# 18.4989087

# %%
pintargrafico(data,atri,4)
# Out:
# Atributo: perimeter_mean
# Varianza:
# 590.4404795

# %%
pintargrafico(data,atri,5)
# Out:
# Atributo: area_mean
# Varianza:
# 123843.5543177

# %%
pintargrafico(data,atri,6)
# Out:
# Atributo: smoothness_mean
# Varianza:
# 0.0001978

# %%
pintargrafico(data,atri,7)
# Out:
# Atributo: compactness_mean
# Varianza:
# 0.0027892

# %%
pintargrafico(data,atri,8)
# Out:
# Atributo: concavity_mean
# Varianza:
# 0.0063552

# %%
pintargrafico(data,atri,9)
# Out:
# Atributo: concave points_mean
# Varianza:
# 0.0015057

# %%
pintargrafico(data,atri,10)
# Out:
# Atributo: symmetry_mean
# Varianza:
# 0.0007515

# %%
pintargrafico(data,atri,11)
# Out:
# Atributo: fractal_dimension_mean
# Varianza:
# 0.0000498

# %%
pintargrafico(data,atri,12)
# Out:
# Atributo: radius_se
# Varianza:
# 0.0769024

# %%
pintargrafico(data,atri,13)
# Out:
# Atributo: texture_se
# Varianza:
# 0.3043159

# %%
pintargrafico(data,atri,14)
# Out:
# Atributo: perimeter_se
# Varianza:
# 4.0878958

# %%
pintargrafico(data,atri,15)
# Out:
# Atributo: area_se
# Varianza:
# 2069.4315829

# %%
pintargrafico(data,atri,16)
# Out:
# Atributo: smoothness_se
# Varianza:
# 0.0000090

# %%
pintargrafico(data,atri,17)
# Out:
# Atributo: compactness_se
# Varianza:
# 0.0003207

# %%
pintargrafico(data,atri,18)
# Out:
# Atributo: concavity_se
# Varianza:
# 0.0009112

# %%
pintargrafico(data,atri,19)
# Out:
# Atributo: concave points_se
# Varianza:
# 0.0000381

# %%
pintargrafico(data,atri,20)
# Out:
# Atributo: symmetry_se
# Varianza:
# 0.0000683

# %%
pintargrafico(data,atri,21)
# Out:
# Atributo: fractal_dimension_se
# Varianza:
# 0.0000070

# %%
pintargrafico(data,atri,22)
# Out:
# Atributo: radius_worst
# Varianza:
# 23.3602242

# %%
pintargrafico(data,atri,23)
# Out:
# Atributo: texture_worst
# Varianza:
# 37.7764828

# %%
pintargrafico(data,atri,24)
# Out:
# Atributo: perimeter_worst
# Varianza:
# 1129.1308469

# %%
pintargrafico(data,atri,25)
# Out:
# Atributo: area_worst
# Varianza:
# 324167.3851022

# %%
pintargrafico(data,atri,26)
# Out:
# Atributo: smoothness_worst
# Varianza:
# 0.0005213

# %%
pintargrafico(data,atri,27)
# Out:
# Atributo: compactness_worst
# Varianza:
# 0.0247548

# %%
pintargrafico(data,atri,28)
# Out:
# Atributo: concavity_worst
# Varianza:
# 0.0435241

# %%
pintargrafico(data,atri,29)
# Out:
# Atributo: concave points_worst
# Varianza:
# 0.0043207

# %%
pintargrafico(data,atri,30)
# Out:
# Atributo: symmetry_worst
# Varianza:
# 0.0038276

# %%
pintargrafico(data,atri,31)
# Out:
# Atributo: fractal_dimension_worst
# Varianza:
# 0.0003262

# %%
df = pd.read_csv('data.csv')

# %%
columnas = ['radius_mean',
 'texture_mean',
 'perimeter_mean',
 'area_mean',
 'smoothness_mean',
 'compactness_mean',
 'concavity_mean',
 'concave points_mean',
 'symmetry_mean',
 'fractal_dimension_mean',
 'radius_se',
 'texture_se',
 'perimeter_se',
 'area_se',
 'smoothness_se',
 'compactness_se',
 'concavity_se',
 'concave points_se',
 'symmetry_se',
 'fractal_dimension_se',
 'radius_worst',
 'texture_worst',
 'perimeter_worst',
 'area_worst',
 'smoothness_worst',
 'compactness_worst',
 'concavity_worst',
 'concave points_worst',
 'symmetry_worst',
 'fractal_dimension_worst']

# %%
corr = df[columnas].corr()

# %%
import seaborn as sns
sns.heatmap(corr,xticklabels=corr.columns.values,yticklabels=corr.columns.values, cmap='RdYlGn')
# Out:
# <AxesSubplot: >

# %%
#Calculamos la varianza y se guardan los datos en varianzas.append, esto nos ayuda a que todo el array se guarde, estas son sin
#normalizar
varianzas = []

for i in range(2,31):
    ndatos = data.iloc[:, i].tolist()
    varx = st.variance(ndatos)
    varround = round(varx,3)
    varianzas.append(varround)

#Calculamos la media de todas las varianzas y la desviación estandar para poder normalizar las varianzas 
med_var = round((np.mean(varianzas)),3)
desv_est = round((np.std(varianzas)),3)

#Calculamos las varianzas normalizadas y la media de esta
var_norm = [round((varround - med_var)/desv_est,3) for varround in varianzas]
med_var_norm = round((np.mean(var_norm)),4)

print("Varianzas sin normalizar:")
print(varianzas)
print("\nMedia de varianzas sin normalizar:", med_var)
print("\nDesviación estándar de varianzas sin normalizar:", desv_est)
print("\nVarianzas normalizadas:")
print(var_norm)
print("\nMedia de varianzas normalizadas:", med_var_norm)
# Out:
# Varianzas sin normalizar:
# [12.419, 18.499, 590.44, 123843.554, 0.0, 0.003, 0.006, 0.002, 0.001, 0.0, 0.077, 0.304, 4.088, 2069.432, 0.0, 0.0, 0.001, 0.0, 0.0, 0.0, 23.36, 37.776, 1129.131, 324167.385, 0.001, 0.025, 0.044, 0.004, 0.004]
#
# Media de varianzas sin normalizar: 15582.64
#
# Desviación estándar de varianzas sin normalizar: 62528.859
#
# Varianzas normalizadas:
# [-0.249, -0.249, -0.24, 1.731, -0.249, -0.249, -0.249, -0.249, -0.249, -0.249, -0.249, -0.249, -0.249, -0.216, -0.249, -0.249, -0.249, -0.249, -0.249, -0.249, -0.249, -0.249, -0.231, 4.935, -0.249, -0.249, -0.249, -0.249, -0.249]
#
# Media de varianzas normalizadas: 0.0001

# %%
#Mostramos la gráfica de las varianzas y cómo actuan
plt.plot(varianzas)
plt.xlabel("Número de columna")
plt.ylabel("Valor de dato")
plt.title("Grafica")
# Out:
# Text(0.5, 1.0, 'Grafica')

# %%
#Función automática para eliminar los outliers utilizando boxplot
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

def eliminarOutliers(data, atri):
    for i in range(len(atri)):
        sns.set(style="whitegrid")

        print("Atributo: " + atri[i])
        datitos = data.loc[:, atri[i]].tolist()

        # Calculamos los cuartiles
        Q1 = np.percentile(datitos, 25)
        Q3 = np.percentile(datitos, 75)

        # Calcular el rango intercuartil (IQR)
        IQR = Q3 - Q1

        # Calcular los bigotes superior e inferior
        bigote_superior = Q3 + 1.5 * IQR
        bigote_inferior = Q1 - 1.5 * IQR

        print("Bigote superior:", bigote_superior)
        print("Bigote inferior:", bigote_inferior)

        # Eliminar los outliers de la base de datos
        data = data[(data[atri[i]] >= bigote_inferior) & (data[atri[i]] <= bigote_superior)]

        # Graficar el boxplot sin outliers
        sns.boxplot(x=data[atri[i]])
        plt.title("Boxplot sin outliers")
        plt.show()

    return data

# %%
columnas = data.columns.tolist() 

for columna in columnas[2:]:
    data = eliminarOutliers(data, [columna])
# Out:
# Atributo: radius_mean
# Bigote superior: 21.8
# Bigote inferior: 5.540000000000002
# Atributo: texture_mean
# Bigote superior: 29.895000000000003
# Bigote inferior: 7.6949999999999985
# Atributo: perimeter_mean
# Bigote superior: 143.31375
# Bigote inferior: 32.943749999999994
# Atributo: area_mean
# Bigote superior: 1192.8249999999998
# Bigote inferior: -61.374999999999886
# Atributo: smoothness_mean
# Bigote superior: 0.13293
# Bigote inferior: 0.056450000000000014
# Atributo: compactness_mean
# Bigote superior: 0.21337875
# Bigote inferior: -0.029831250000000017
# Atributo: concavity_mean
# Bigote superior: 0.208805
# Bigote inferior: -0.082995
# Atributo: concave points_mean
# Bigote superior: 0.10575875000000001
# Bigote inferior: -0.03363125
# Atributo: symmetry_mean
# Bigote superior: 0.2412875
# Bigote inferior: 0.11138749999999999
# Atributo: fractal_dimension_mean
# Bigote superior: 0.077455
# Bigote inferior: 0.045775
# Atributo: radius_se
# Bigote superior: 0.6517
# ...

# %%
data
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19   8510426         B       13.540         14.36           87.46      566.3
# 20   8510653         B       13.080         15.71           85.63      520.0
# 21   8510824         B        9.504         12.44           60.34      273.9
# 37    854941         B       13.030         18.42           82.61      523.8
# 40    855167         M       13.440         21.58           86.18      563.0
# ..       ...       ...          ...           ...             ...        ...
# 551   923780         B       11.130         22.44           71.49      378.4
# 552   924084         B       12.770         29.43           81.35      507.9
# 554   924632         B       12.880         28.92           82.50      514.3
# 555   924934         B       10.290         27.61           65.67      321.4
# 560   925292         B       14.050         27.15           91.38      600.4
#
# ...

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV, cross_val_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# Preprocesamiento de datos
label_encoder = LabelEncoder()
features = data.drop(['id', 'diagnosis'], axis=1)
labels = label_encoder.fit_transform(data['diagnosis'])

scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)

# División de datos en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(features_scaled, labels, test_size=0.3, random_state=33)

# Definición de la función para crear el modelo
def create_model():
    model = Sequential()
    model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(80, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Creación del clasificador Keras
keras_classifier = KerasClassifier(build_fn=create_model)

# Definición de los hiperparámetros para la búsqueda aleatoria
param_grid = {
    'batch_size': [32, 64, 128],
    'epochs': [10, 20, 30],
}

# Realización de la búsqueda aleatoria de hiperparámetros con validación cruzada
random_search = RandomizedSearchCV(keras_classifier, param_grid, cv=3)
random_search.fit(X_train, y_train)

# Mejores hiperparámetros encontrados
print("Mejores hiperparámetros encontrados:")
print(random_search.best_params_)

# Evaluación del modelo con los mejores hiperparámetros utilizando validación cruzada
best_model = random_search.best_estimator_
scores = cross_val_score(best_model, X_test, y_test, cv=3)
print('Accuracy promedio:', np.mean(scores))
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5776\4090184533.py:31: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_classifier = KerasClassifier(build_fn=create_model)
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:306: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Epoch 1/10
# 9/9 [==============================] - 1s 3ms/step - loss: 0.6382 - accuracy: 0.7623
# Epoch 2/10
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5027 - accuracy: 0.8528
# Epoch 3/10
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3356 - accuracy: 0.8906
# Epoch 4/10
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2218 - accuracy: 0.9208
# Epoch 5/10
# ...

# %%
#Entrenamiento red neuronal
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Preprocesamiento de datos
label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(data['diagnosis'])

scaler = MinMaxScaler()
features = data.drop(['id', 'diagnosis'], axis=1)
features_scaled = scaler.fit_transform(features)

# División de datos en conjunto de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(features_scaled, labels, test_size=0.3, random_state=22)

# Definición del modelo
model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(88, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

# Compilación del modelo
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Entrenamiento del modelo
model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)

# Evaluación del modelo en el conjunto de prueba
loss, accuracy = model.evaluate(X_test, y_test)
print('Loss:', loss)
print('Accuracy:', accuracy)
# Out:
# Epoch 1/30
# 13/13 [==============================] - 1s 4ms/step - loss: 0.6847 - accuracy: 0.4975
# Epoch 2/30
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6299 - accuracy: 0.8166
# Epoch 3/30
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4844 - accuracy: 0.8643
# Epoch 4/30
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3504 - accuracy: 0.8618
# Epoch 5/30
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2735 - accuracy: 0.8945
# Epoch 6/30
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.9146
# Epoch 7/30
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2130 - accuracy: 0.9146
# Epoch 8/30
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1994 - accuracy: 0.9271
# Epoch 9/30
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1964 - accuracy: 0.9296
# Epoch 10/30
# ...

# %%
def predecirMalignidad(id_especifico, model, scaler, data):
    
    if id_especifico not in data['id'].values:
        return "ID no encontrado"
    
    datos_id = data.loc[data['id'] == id_especifico, data.columns[2:]]
    
    if datos_id.empty:
        return "Datos vacíos para el ID específico"
    
    datos_id = scaler.transform(datos_id)
    
    prediccion = model.predict(datos_id)
    
    if prediccion[0] < 0.5:
        resultado = "Benigno"
    else:
        resultado = "Maligno"
    
    return resultado

# %%
predecirMalignidad(855167, model, scaler, data)
# Out:
# 1/1 [==============================] - 0s 56ms/step
# 'Benigno'

# %%
#Probando con AuC
from sklearn.metrics import roc_auc_score
import tensorflow as tf

# Definir el modelo
model = Sequential()
model.add(Dense(120, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(100, activation='relu'))
model.add(Dense(80, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo con la métrica AUC
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[tf.keras.metrics.AUC()])
    
# Entrenar el modelo
model.fit(X_train, y_train, epochs=11, batch_size=20)

# Realizar la predicción en el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular el AUC
auc = roc_auc_score(y_test, y_pred)
print('AUC:', auc)
# Out:
# Epoch 1/11
# 20/20 [==============================] - 1s 3ms/step - loss: 0.6271 - auc: 0.7039
# Epoch 2/11
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4728 - auc: 0.9216
# Epoch 3/11
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3368 - auc: 0.9619
# Epoch 4/11
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2282 - auc: 0.9779
# Epoch 5/11
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1481 - auc: 0.9901
# Epoch 6/11
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1059 - auc: 0.9944
# Epoch 7/11
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0972 - auc: 0.9941
# Epoch 8/11
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0693 - auc: 0.9978
# Epoch 9/11
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0705 - auc: 0.9965
# Epoch 10/11
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0565 - auc: 0.9983
# Epoch 11/11
# ...

# %%
data
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19   8510426         B       13.540         14.36           87.46      566.3
# 20   8510653         B       13.080         15.71           85.63      520.0
# 21   8510824         B        9.504         12.44           60.34      273.9
# 37    854941         B       13.030         18.42           82.61      523.8
# 40    855167         M       13.440         21.58           86.18      563.0
# ..       ...       ...          ...           ...             ...        ...
# 551   923780         B       11.130         22.44           71.49      378.4
# 552   924084         B       12.770         29.43           81.35      507.9
# 554   924632         B       12.880         28.92           82.50      514.3
# 555   924934         B       10.290         27.61           65.67      321.4
# 560   925292         B       14.050         27.15           91.38      600.4
#
# ...

# %%
# Establecer las opciones para mostrar el dataset completo
pd.set_option('display.max_rows', None)  # Mostrar todas las filas
pd.set_option('display.max_columns', None)  # Mostrar todas las columnas

# Mostrar el dataset completo
print(data)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19   8510426         B       13.540         14.36           87.46      566.3
# 20   8510653         B       13.080         15.71           85.63      520.0
# 21   8510824         B        9.504         12.44           60.34      273.9
# 37    854941         B       13.030         18.42           82.61      523.8
# 40    855167         M       13.440         21.58           86.18      563.0
# 43    856106         M       13.280         20.28           87.32      545.2
# 48    857155         B       12.050         14.63           78.04      449.3
# 49    857156         B       13.490         22.30           86.91      561.0
# 50    857343         B       11.760         21.60           74.72      427.9
# 51    857373         B       13.640         16.34           87.21      571.8
# 52    857374         B       11.940         18.24           75.71      437.6
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Obtener los pesos de las conexiones de las capas
weights = model.get_weights()

# Calcular la importancia de características sumando los pesos absolutos de cada conexión para cada atributo
feature_importance = np.abs(weights[0]).sum(axis=1)

# Obtener los nombres de los atributos
feature_names = data.columns[2:]

# Crear un gráfico de barras para visualizar la importancia de características
plt.figure(figsize=(10, 6))
plt.barh(feature_names, feature_importance)
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.show()
